# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns

# %%
data = pd.read_csv('Combined Closed Business.csv', encoding='latin-1')

# %%
data.head()
# Out:
#                      Company Name Executive First Name Executive Last Name  \
# 0                 235 Media Group                 Bill           Hennessey
# 1                 42nd Estate LLC                 Adam           Pieniazek
# 2                 732 Numbers LLC                  NaN                 NaN
# 3                      97 Circuit                  NaN                 NaN
# 4  A & A House Keeping & Catering                  NaN                 NaN
#
#             Address        City State  ZIP Code Credit Score Alpha  \
# 0  235 Minot St # 3  Dorchester    MA      2124                  A
# 1   47 Roseclair St  Dorchester    MA      2125                 B+
# 2      175 Adams St  Dorchester    MA      2122                 B+
# 3     97 Circuit St     Roxbury    MA      2119                  A
# 4         42 Fox St  Dorchester    MA      2122                 C+
#
#   Executive Gender Executive Title  Fax Number Combined  IUSA Number  \
# 0             Male           Owner                  NaN  71-113-8265
# 1             Male           Owner                  NaN  40-046-5272
# 2              NaN             NaN                  NaN  70-639-7248
# 3              NaN             NaN                  NaN  42-512-6286
# 4              NaN             NaN                  NaN  42-778-2839
#
#   Location Employee Size Range Location Sales Volume Range  \
# 0                       5 to 9              $1-2.5 Million
# 1                       1 to 4          Less Than $500,000
# 2                     20 to 49              $20-50 Million
# 3                       5 to 9          $500,000-1 Million
# 4                       1 to 4          Less Than $500,000
#
#   Phone Number Combined  Primary SIC Code Primary SIC Description  SIC Code 1  \
# 0        (617) 637-0515            737311  Website Design Service      737311
# 1        (617) 288-4185            653118             Real Estate      653118
# 2        (617) 825-5263            481304     Telephone Companies      481304
# 3        (617) 427-9797            653118             Real Estate      653118
# 4        (617) 326-6487            734922          House Cleaning      734922
#
#    SIC Code 1 Description             Record Type
# 0  Website Design Service  Closed/Out of Business
# 1             Real Estate  Closed/Out of Business
# 2     Telephone Companies  Closed/Out of Business
# 3             Real Estate  Closed/Out of Business
# 4          House Cleaning  Closed/Out of Business

# %%
data.dtypes
data.isnull().sum()
data.shape
# Out:
# (829, 20)

# %%
sns.catplot(y='City',
           kind='count',
            height=4, 
            aspect=1.5,
            order=data.City.value_counts().index,
           data=data)

# %%
sns.catplot(x='Location Employee Size Range',
           kind='count',
            height=8, 
            aspect=4.5,
            #color='black',
           data=data)
plt.xticks(size=25)
plt.yticks(size=25)
plt.xlabel('Size', fontsize=40)
plt.ylabel('Count', fontsize=40)
# Out:
# Text(3.8000000000000043, 0.5, 'Count')

# %%
data1 = pd.read_csv('crime_incident.csv', encoding='latin-1')

# %%
data1.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE OFFENSE_CODE_GROUP   OFFENSE_DESCRIPTION  \
# 0       TESTTEST2           423                NaN  ASSAULT - AGGRAVATED
# 1       I92089785          3005                NaN           SICK ASSIST
# 2       I90583827          1402                NaN             VANDALISM
# 3      I192082859           724         Auto Theft            AUTO THEFT
# 4      I192082751           724         Auto Theft            AUTO THEFT
#
#    DISTRICT REPORTING_AREA SHOOTING     OCCURRED_ON_DATE  YEAR  MONTH  \
# 0  External                       0  2019-10-16 00:00:00  2019     10
# 1       E13            574        0  2019-11-05 18:00:00  2019     11
# 2       E18            498        0  2019-11-02 05:09:00  2019     11
# 3       E18            519      NaN  2019-10-13 09:28:24  2019     10
# 4       E18            493      NaN  2019-10-12 20:11:26  2019     10
#
#   DAY_OF_WEEK  HOUR  UCR_PART            STREET        Lat       Long  \
# 0   Wednesday     0       NaN      RIVERVIEW DR        NaN        NaN
# 1     Tuesday    18       NaN     WASHINGTON ST        NaN        NaN
# 2    Saturday     5       NaN        BRADLEE ST        NaN        NaN
# 3      Sunday     9  Part One        LINCOLN ST  42.259518 -71.121563
# 4    Saturday    20  Part One  METROPOLITAN AVE  42.262092 -71.116710
#
#                       Location
# 0     (0.00000000, 0.00000000)
# 1     (0.00000000, 0.00000000)
# 2     (0.00000000, 0.00000000)
# 3  (42.25951765, -71.12156299)
# 4  (42.26209214, -71.11670964)

# %%
data1 = data1.loc[data1['YEAR'].isin([2018,2019])]

# %%
data1 = data1.loc[data1['UCR_PART'] == 'Part One']

# %%
# Remove unused columns
data1 = data1.drop(['INCIDENT_NUMBER','OFFENSE_CODE','UCR_PART','Location'], axis=1)

# Convert OCCURED_ON_DATE to datetime
data1['OCCURRED_ON_DATE'] = pd.to_datetime(data1['OCCURRED_ON_DATE'])

# Fill in nans in SHOOTING column
data1.SHOOTING.fillna('N', inplace=True)

# Convert DAY_OF_WEEK to an ordered category
data1.DAY_OF_WEEK = pd.Categorical(data1.DAY_OF_WEEK, 
              categories=['Monday','Tuesday','Wednesday','Thursday','Friday','Saturday','Sunday'],
              ordered=True)

# Replace -1 values in Lat/Long with Nan
data1.Lat.replace(-1, None, inplace=True)
data1.Long.replace(-1, None, inplace=True)

# Rename columns to something easier to type (the all-caps are annoying!)
rename = {'OFFENSE_CODE_GROUP':'Group',
         'OFFENSE_DESCRIPTION':'Description',
         'DISTRICT':'District',
         'REPORTING_AREA':'Area',
         'SHOOTING':'Shooting',
         'OCCURRED_ON_DATE':'Date',
         'YEAR':'Year',
         'MONTH':'Month',
         'DAY_OF_WEEK':'Day',
         'HOUR':'Hour',
         'STREET':'Street'}
data1.rename(index=str, columns=rename, inplace=True)

# Check
data1.head()
# Out:
#         Group                         Description District Area Shooting  \
# 3  Auto Theft                          AUTO THEFT      E18  519        N
# 4  Auto Theft                          AUTO THEFT      E18  493        N
# 5  Auto Theft  AUTO THEFT - LEASED/RENTED VEHICLE      D14  794        N
# 6  Auto Theft                          AUTO THEFT       D4  130        N
# 7  Auto Theft  AUTO THEFT - LEASED/RENTED VEHICLE      A15   47        N
#
#                  Date  Year  Month        Day  Hour            Street  \
# 3 2019-10-13 09:28:24  2019     10     Sunday     9        LINCOLN ST
# 4 2019-10-12 20:11:26  2019     10   Saturday    20  METROPOLITAN AVE
# 5 2019-10-12 15:12:43  2019     10   Saturday    15        ALLSTON ST
# 6 2019-10-12 04:41:52  2019     10   Saturday     4   SAINT JAMES AVE
# 7 2019-10-02 08:08:49  2019     10  Wednesday     8         N MEAD ST
#
#          Lat       Long
# 3  42.259518 -71.121563
# 4  42.262092 -71.116710
# 5  42.352375 -71.135096
# 6  42.349476 -71.076402
# 7  42.381846 -71.066551

# %%
# A few more data checks
data1.dtypes
data1.isnull().sum()
data1.shape
# Out:
# (30720, 13)

# %%
# Plot districts
sns.scatterplot(x='Lat',
               y='Long',
                hue='District',
                alpha=0.01,
               data=data1)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2)

# %%
import folium
from folium.plugins import HeatMap

# %%
# Create basic Folium crime map
#crime_map = folium.Map(location=[42.3125,-71.0875], 
crime_map = folium.Map(location=[42.3125,-71.0875], 
                       tiles = "Stamen Toner",
                      zoom_start = 11)

# Add data for heatmp 
data_heatmap = data1[data1.Year == 2018]
data_heatmap = data1[['Lat','Long']]
data_heatmap = data1.dropna(axis=0, subset=['Lat','Long'])
data_heatmap = [[row['Lat'],row['Long']] for index, row in data_heatmap.iterrows()]
HeatMap(data_heatmap, radius=10).add_to(crime_map)

# Plot!
crime_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
